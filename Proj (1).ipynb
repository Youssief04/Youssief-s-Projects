# %%
import pandas as pd

# %%
df=pd.read_csv("D:/Data Science/garments_worker_productivity.csv")
df
# Out:
#             date   quarter  department        day  team  \
# 0     01/01/2015  Quarter1      sweing   Thursday     8
# 1     01/01/2015  Quarter1  finishing    Thursday     1
# 2     01/01/2015  Quarter1      sweing   Thursday    11
# 3     01/01/2015  Quarter1      sweing   Thursday    12
# 4     01/01/2015  Quarter1      sweing   Thursday     6
# ...          ...       ...         ...        ...   ...
# 1192  03/11/2015  Quarter2   finishing  Wednesday    10
# 1193  03/11/2015  Quarter2   finishing  Wednesday     8
# 1194  03/11/2015  Quarter2   finishing  Wednesday     7
# 1195  03/11/2015  Quarter2   finishing  Wednesday     9
# 1196  03/11/2015  Quarter2   finishing  Wednesday     6
#
#       targeted_productivity    smv     wip  over_time  incentive  idle_tim  \
# 0                      0.80  26.16  1108.0       7080         98       0.0
# 1                      0.75   3.94     NaN        960          0       0.0
# ...

# %%
df.dtypes
# Out:
# date                      object
# quarter                   object
# department                object
# day                       object
# team                       int64
# targeted_productivity    float64
# smv                      float64
# wip                      float64
# over_time                  int64
# incentive                  int64
# idle_tim                 float64
# idle_men                   int64
# no_of_style_change         int64
# no_of_workers            float64
# actual_productivity      float64
# dtype: object

# %%
df.isna().sum()
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_tim                   0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(df, kind="scatter", plot_kws={'alpha':0.4})
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
dfm=['wip','targeted_productivity','over_time','smv','incentive','idle_men','no_of_style_change','actual_productivity']
dfmean=df[dfm].mean()
dfmean
# Out:
# wip                      1190.465991
# targeted_productivity       0.729632
# over_time                4567.460317
# smv                        15.062172
# incentive                  38.210526
# idle_men                    0.369256
# no_of_style_change          0.150376
# actual_productivity         0.735091
# dtype: float64

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_tim                   0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
df['wip'].fillna(0, inplace=True)
df
# Out:
#             date   quarter  department        day  team  \
# 0     01/01/2015  Quarter1      sweing   Thursday     8
# 1     01/01/2015  Quarter1  finishing    Thursday     1
# 2     01/01/2015  Quarter1      sweing   Thursday    11
# 3     01/01/2015  Quarter1      sweing   Thursday    12
# 4     01/01/2015  Quarter1      sweing   Thursday     6
# ...          ...       ...         ...        ...   ...
# 1192  03/11/2015  Quarter2   finishing  Wednesday    10
# 1193  03/11/2015  Quarter2   finishing  Wednesday     8
# 1194  03/11/2015  Quarter2   finishing  Wednesday     7
# 1195  03/11/2015  Quarter2   finishing  Wednesday     9
# 1196  03/11/2015  Quarter2   finishing  Wednesday     6
#
#       targeted_productivity    smv     wip  over_time  incentive  idle_tim  \
# 0                      0.80  26.16  1108.0       7080         98       0.0
# 1                      0.75   3.94     0.0        960          0       0.0
# ...

# %%
df_no_duplicates = df.drop_duplicates()
df_no_duplicates
# Out:
#             date   quarter  department        day  team  \
# 0     01/01/2015  Quarter1      sweing   Thursday     8
# 1     01/01/2015  Quarter1  finishing    Thursday     1
# 2     01/01/2015  Quarter1      sweing   Thursday    11
# 3     01/01/2015  Quarter1      sweing   Thursday    12
# 4     01/01/2015  Quarter1      sweing   Thursday     6
# ...          ...       ...         ...        ...   ...
# 1192  03/11/2015  Quarter2   finishing  Wednesday    10
# 1193  03/11/2015  Quarter2   finishing  Wednesday     8
# 1194  03/11/2015  Quarter2   finishing  Wednesday     7
# 1195  03/11/2015  Quarter2   finishing  Wednesday     9
# 1196  03/11/2015  Quarter2   finishing  Wednesday     6
#
#       targeted_productivity    smv     wip  over_time  incentive  idle_tim  \
# 0                      0.80  26.16  1108.0       7080         98       0.0
# 1                      0.75   3.94     0.0        960          0       0.0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
cat_columns =['department']
cat_columns
encoder = OneHotEncoder(drop='first', sparse_output=False)
cat_encoded = encoder.fit_transform(df[cat_columns])
feature_names = encoder.get_feature_names_out(cat_columns)
cat_encoded_df = pd.DataFrame(cat_encoded, columns=feature_names)
df=pd.concat([df.drop(columns=cat_columns), cat_encoded_df],axis=1)
df
# Out:
#             date   quarter        day  team  targeted_productivity    smv  \
# 0     01/01/2015  Quarter1   Thursday     8                   0.80  26.16
# 1     01/01/2015  Quarter1   Thursday     1                   0.75   3.94
# 2     01/01/2015  Quarter1   Thursday    11                   0.80  11.41
# 3     01/01/2015  Quarter1   Thursday    12                   0.80  11.41
# 4     01/01/2015  Quarter1   Thursday     6                   0.80  25.90
# ...          ...       ...        ...   ...                    ...    ...
# 1192  03/11/2015  Quarter2  Wednesday    10                   0.75   2.90
# 1193  03/11/2015  Quarter2  Wednesday     8                   0.70   3.90
# 1194  03/11/2015  Quarter2  Wednesday     7                   0.65   3.90
# 1195  03/11/2015  Quarter2  Wednesday     9                   0.75   2.90
# 1196  03/11/2015  Quarter2  Wednesday     6                   0.70   2.90
#
#          wip  over_time  incentive  idle_tim  idle_men  no_of_style_change  \
# ...

# %%
df
# Out:
#             date   quarter        day  team  targeted_productivity    smv  \
# 0     01/01/2015  Quarter1   Thursday     8                   0.80  26.16
# 1     01/01/2015  Quarter1   Thursday     1                   0.75   3.94
# 2     01/01/2015  Quarter1   Thursday    11                   0.80  11.41
# 3     01/01/2015  Quarter1   Thursday    12                   0.80  11.41
# 4     01/01/2015  Quarter1   Thursday     6                   0.80  25.90
# ...          ...       ...        ...   ...                    ...    ...
# 1192  03/11/2015  Quarter2  Wednesday    10                   0.75   2.90
# 1193  03/11/2015  Quarter2  Wednesday     8                   0.70   3.90
# 1194  03/11/2015  Quarter2  Wednesday     7                   0.65   3.90
# 1195  03/11/2015  Quarter2  Wednesday     9                   0.75   2.90
# 1196  03/11/2015  Quarter2  Wednesday     6                   0.70   2.90
#
#          wip  over_time  incentive  idle_tim  idle_men  no_of_style_change  \
# ...

# %%
num_columns = ['wip','targeted_productivity','over_time','smv','incentive','idle_men','no_of_style_change','actual_productivity']

# %%
num_columns
# Out:
# ['wip',
#  'targeted_productivity',
#  'over_time',
#  'smv',
#  'incentive',
#  'idle_men',
#  'no_of_style_change',
#  'actual_productivity']

# %%
scaler = MinMaxScaler()

# %%
df[num_columns] = scaler.fit_transform(df[num_columns])

# %%
df
# Out:
#             date   quarter        day  team  targeted_productivity       smv  \
# 0     01/01/2015  Quarter1   Thursday     8               1.000000  0.450252
# 1     01/01/2015  Quarter1   Thursday     1               0.931507  0.020132
# 2     01/01/2015  Quarter1   Thursday    11               1.000000  0.164731
# 3     01/01/2015  Quarter1   Thursday    12               1.000000  0.164731
# 4     01/01/2015  Quarter1   Thursday     6               1.000000  0.445219
# ...          ...       ...        ...   ...                    ...       ...
# 1192  03/11/2015  Quarter2  Wednesday    10               0.931507  0.000000
# 1193  03/11/2015  Quarter2  Wednesday     8               0.863014  0.019357
# 1194  03/11/2015  Quarter2  Wednesday     7               0.794521  0.019357
# 1195  03/11/2015  Quarter2  Wednesday     9               0.931507  0.000000
# 1196  03/11/2015  Quarter2  Wednesday     6               0.863014  0.000000
#
# ...
